# %%
# !pip install numpy tensorflow==2.9.1 tensorflow_datasets==4.6.0

from __future__ import absolute_import, division, print_function, unicode_literals

import sys

import os
import re
import numpy as np
from time import time
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

tf.keras.utils.set_random_seed(1234)

print(f"Tensorflow version {tf.__version__}")
# Out:
# Tensorflow version 2.9.1

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print("Running on TPU {}".format(tpu.cluster_spec().as_dict()["worker"]))
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
print(f"REPLICAS: {strategy.num_replicas_in_sync}")
# Out:
# REPLICAS: 1

# %%
def preprocess_sentence(sentence):
    sentence = sentence.lower().strip()
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    # removing contractions
    sentence = re.sub(r"i'm", "i am", sentence)
    sentence = re.sub(r"he's", "he is", sentence)
    sentence = re.sub(r"she's", "she is", sentence)
    sentence = re.sub(r"it's", "it is", sentence)
    sentence = re.sub(r"that's", "that is", sentence)
    sentence = re.sub(r"what's", "that is", sentence)
    sentence = re.sub(r"where's", "where is", sentence)
    sentence = re.sub(r"how's", "how is", sentence)
    sentence = re.sub(r"\'ll", " will", sentence)
    sentence = re.sub(r"\'ve", " have", sentence)
    sentence = re.sub(r"\'re", " are", sentence)
    sentence = re.sub(r"\'d", " would", sentence)
    sentence = re.sub(r"\'re", " are", sentence)
    sentence = re.sub(r"won't", "will not", sentence)
    sentence = re.sub(r"can't", "cannot", sentence)
    sentence = re.sub(r"n't", " not", sentence)
    sentence = re.sub(r"n'", "ng", sentence)
    sentence = re.sub(r"'bout", "about", sentence)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    sentence = re.sub(r"[^a-zA-Z?.!,]+", " ", sentence)
    sentence = sentence.strip()
    return sentence

# %%
import pandas as pd
file = pd.read_csv("One_Up_On_Wall_Street_QandA_Full.csv")
questions = []
answers = []
for index, row in file.iterrows():
    questions.append(preprocess_sentence(row["question"]))
    answers.append(preprocess_sentence(row["answer"]))

# %%
questions[0]
# Out:
# 'why does peter lynch believe his investment principles still apply today ?'

# %%
answers[0]
# Out:
# 'lynch believes that the basic principles of observing businesses understanding earnings and focusing on longterm growth are timeless and remain effective despite changing market conditions'

# %%
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13
)

# Define start and end token to indicate the start and end of a sentence
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# Vocabulary size plus start and end token
VOCAB_SIZE = tokenizer.vocab_size + 2

print(f"Tokenized sample question: {tokenizer.encode(questions[98])}")
# Out:
# Tokenized sample question: [14, 6, 1, 272, 5, 873, 10, 212, 50, 766, 212, 532, 2]

# %%
MAX_LENGTH = 40

# Maximum number of samples to preprocess
MAX_SAMPLES = 50000

# For tf.data.Dataset
BATCH_SIZE = 64 * strategy.num_replicas_in_sync
BUFFER_SIZE = 20000

# For Transformer
NUM_LAYERS = 2
D_MODEL = 256
NUM_HEADS = 8
UNITS = 512
DROPOUT = 0.1

EPOCHS = 40

# Tokenize, filter and pad sentences
def tokenize_and_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []

    for (sentence1, sentence2) in zip(inputs, outputs):
        # tokenize sentence
        sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
        sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN
        # check tokenized sentence max length
        if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
            tokenized_inputs.append(sentence1)
            tokenized_outputs.append(sentence2)

    # pad tokenized sentences
    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_inputs, maxlen=MAX_LENGTH, padding="post"
    )
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_outputs, maxlen=MAX_LENGTH, padding="post"
    )

    return tokenized_inputs, tokenized_outputs


questions, answers = tokenize_and_filter(questions, answers)

# %%
dataset = tf.data.Dataset.from_tensor_slices(
    (
        {"inputs": questions, "dec_inputs": answers[:, :-1]},
        {"outputs": answers[:, 1:]},
    )
)

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.AUTOTUNE)

# %%
dataset
# Out:
# <PrefetchDataset element_spec=({'inputs': TensorSpec(shape=(None, 40), dtype=tf.int32, name=None), 'dec_inputs': TensorSpec(shape=(None, 39), dtype=tf.int32, name=None)}, {'outputs': TensorSpec(shape=(None, 39), dtype=tf.int32, name=None)})>

# %%
def scaled_dot_product_attention(query, key, value, mask):
    """Calculate the attention weights."""
    matmul_qk = tf.matmul(query, key, transpose_b=True)

    # scale matmul_qk
    depth = tf.cast(tf.shape(key)[-1], tf.float32)
    logits = matmul_qk / tf.math.sqrt(depth)

    # add the mask to zero out padding tokens
    if mask is not None:
        logits += mask * -1e9

    # softmax is normalized on the last axis (seq_len_k)
    attention_weights = tf.nn.softmax(logits, axis=-1)

    output = tf.matmul(attention_weights, value)

    return output

# %%
class MultiHeadAttentionLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, **kwargs):
        assert d_model % num_heads == 0
        super(MultiHeadAttentionLayer, self).__init__(**kwargs)
        self.num_heads = num_heads
        self.d_model = d_model

        self.depth = d_model // self.num_heads

        self.query_dense = tf.keras.layers.Dense(units=d_model)
        self.key_dense = tf.keras.layers.Dense(units=d_model)
        self.value_dense = tf.keras.layers.Dense(units=d_model)

        self.dense = tf.keras.layers.Dense(units=d_model)

    def get_config(self):
        config = super(MultiHeadAttentionLayer, self).get_config()
        config.update(
            {
                "num_heads": self.num_heads,
                "d_model": self.d_model,
            }
        )
        return config

    def split_heads(self, inputs, batch_size):
        inputs = tf.keras.layers.Lambda(
            lambda inputs: tf.reshape(
                inputs, shape=(batch_size, -1, self.num_heads, self.depth)
            )
        )(inputs)
        return tf.keras.layers.Lambda(
            lambda inputs: tf.transpose(inputs, perm=[0, 2, 1, 3])
        )(inputs)

    def call(self, inputs):
        query, key, value, mask = (
            inputs["query"],
            inputs["key"],
            inputs["value"],
            inputs["mask"],
        )
        batch_size = tf.shape(query)[0]

        # linear layers
        query = self.query_dense(query)
        key = self.key_dense(key)
        value = self.value_dense(value)

        # split heads
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        # scaled dot-product attention
        scaled_attention = scaled_dot_product_attention(query, key, value, mask)
        scaled_attention = tf.keras.layers.Lambda(
            lambda scaled_attention: tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        )(scaled_attention)

        # concatenation of heads
        concat_attention = tf.keras.layers.Lambda(
            lambda scaled_attention: tf.reshape(
                scaled_attention, (batch_size, -1, self.d_model)
            )
        )(scaled_attention)

        # final linear layer
        outputs = self.dense(concat_attention)

        return outputs

# %%
def create_padding_mask(x):
    mask = tf.cast(tf.math.equal(x, 0), tf.float32)
    # (batch_size, 1, 1, sequence length)
    return mask[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(x):
    seq_len = tf.shape(x)[1]
    look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
    padding_mask = create_padding_mask(x)
    return tf.maximum(look_ahead_mask, padding_mask)

# %%
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position, d_model, **kwargs):
        super(PositionalEncoding, self).__init__(**kwargs)
        self.position = position
        self.d_model = d_model
        self.pos_encoding = self.positional_encoding(position, d_model)

    def get_config(self):
        config = super(PositionalEncoding, self).get_config()
        config.update(
            {
                "position": self.position,
                "d_model": self.d_model,
            }
        )
        return config

    def get_angles(self, position, i, d_model):
        angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
        return position * angles

    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
            i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
            d_model=d_model,
        )
        # apply sin to even index in the array
        sines = tf.math.sin(angle_rads[:, 0::2])
        # apply cos to odd index in the array
        cosines = tf.math.cos(angle_rads[:, 1::2])

        pos_encoding = tf.concat([sines, cosines], axis=-1)
        pos_encoding = pos_encoding[tf.newaxis, ...]
        return tf.cast(pos_encoding, tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, : tf.shape(inputs)[1], :]

# %%
sample_pos_encoding = PositionalEncoding(50, 512, name="sample_pos_encoding")

plt.pcolormesh(sample_pos_encoding.pos_encoding.numpy()[0], cmap="RdBu")
plt.xlabel("Depth")
plt.xlim((0, 512))
plt.ylabel("Position")
plt.colorbar()
plt.show()

# %%
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
    inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    attention = MultiHeadAttentionLayer(d_model, num_heads, name="attention")(
        {"query": inputs, "key": inputs, "value": inputs, "mask": padding_mask}
    )
    attention = tf.keras.layers.Dropout(rate=dropout)(attention)
    add_attention = tf.keras.layers.add([inputs, attention])
    attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)(add_attention)

    outputs = tf.keras.layers.Dense(units=units, activation="relu")(attention)
    outputs = tf.keras.layers.Dense(units=d_model)(outputs)
    outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
    add_attention = tf.keras.layers.add([attention, outputs])
    outputs = tf.keras.layers.LayerNormalization(epsilon=1e-6)(add_attention)

    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
sample_encoder_layer = encoder_layer(
    units=512, d_model=128, num_heads=4, dropout=0.3, name="sample_encoder_layer"
)

tf.keras.utils.plot_model(
    sample_encoder_layer, to_file="encoder_layer.png", show_shapes=True
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
def encoder(vocab_size, num_layers, units, d_model, num_heads, dropout, name="encoder"):
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
    embeddings *= tf.keras.layers.Lambda(
        lambda d_model: tf.math.sqrt(tf.cast(d_model, tf.float32))
    )(d_model)
    embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

    outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

    for i in range(num_layers):
        outputs = encoder_layer(
            units=units,
            d_model=d_model,
            num_heads=num_heads,
            dropout=dropout,
            name="encoder_layer_{}".format(i),
        )([outputs, padding_mask])

    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
sample_encoder = encoder(
    vocab_size=8192,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder",
)

# %%
def decoder_layer(units, d_model, num_heads, dropout, name="decoder_layer"):
    inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
    enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
    look_ahead_mask = tf.keras.Input(shape=(1, None, None), name="look_ahead_mask")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    attention1 = MultiHeadAttentionLayer(d_model, num_heads, name="attention_1")(
        inputs={
            "query": inputs,
            "key": inputs,
            "value": inputs,
            "mask": look_ahead_mask,
        }
    )
    add_attention = tf.keras.layers.add([attention1, inputs])
    attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(add_attention)

    attention2 = MultiHeadAttentionLayer(d_model, num_heads, name="attention_2")(
        inputs={
            "query": attention1,
            "key": enc_outputs,
            "value": enc_outputs,
            "mask": padding_mask,
        }
    )
    attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
    add_attention = tf.keras.layers.add([attention2, attention1])
    attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(add_attention)

    outputs = tf.keras.layers.Dense(units=units, activation="relu")(attention2)
    outputs = tf.keras.layers.Dense(units=d_model)(outputs)
    outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
    add_attention = tf.keras.layers.add([outputs, attention2])
    outputs = tf.keras.layers.LayerNormalization(epsilon=1e-6)(add_attention)

    return tf.keras.Model(
        inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
        outputs=outputs,
        name=name,
    )

# %%
sample_decoder_layer = decoder_layer(
    units=512, d_model=128, num_heads=4, dropout=0.3, name="sample_decoder_layer"
)

tf.keras.utils.plot_model(
    sample_decoder_layer, to_file="decoder_layer.png", show_shapes=True
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
def decoder(vocab_size, num_layers, units, d_model, num_heads, dropout, name="decoder"):
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
    look_ahead_mask = tf.keras.Input(shape=(1, None, None), name="look_ahead_mask")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

    embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
    embeddings *= tf.keras.layers.Lambda(
        lambda d_model: tf.math.sqrt(tf.cast(d_model, tf.float32))
    )(d_model)
    embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

    outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

    for i in range(num_layers):
        outputs = decoder_layer(
            units=units,
            d_model=d_model,
            num_heads=num_heads,
            dropout=dropout,
            name="decoder_layer_{}".format(i),
        )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

    return tf.keras.Model(
        inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
        outputs=outputs,
        name=name,
    )

# %%
sample_decoder = decoder(
    vocab_size=8192,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_decoder",
)

tf.keras.utils.plot_model(sample_decoder, to_file="decoder.png", show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
def transformer(
    vocab_size, num_layers, units, d_model, num_heads, dropout, name="transformer"
):
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

    enc_padding_mask = tf.keras.layers.Lambda(
        create_padding_mask, output_shape=(1, 1, None), name="enc_padding_mask"
    )(inputs)
    # mask the future tokens for decoder inputs at the 1st attention block
    look_ahead_mask = tf.keras.layers.Lambda(
        create_look_ahead_mask, output_shape=(1, None, None), name="look_ahead_mask"
    )(dec_inputs)
    # mask the encoder outputs for the 2nd attention block
    dec_padding_mask = tf.keras.layers.Lambda(
        create_padding_mask, output_shape=(1, 1, None), name="dec_padding_mask"
    )(inputs)

    enc_outputs = encoder(
        vocab_size=vocab_size,
        num_layers=num_layers,
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
    )(inputs=[inputs, enc_padding_mask])

    dec_outputs = decoder(
        vocab_size=vocab_size,
        num_layers=num_layers,
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
    )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

    outputs = tf.keras.layers.Dense(units=vocab_size, name="outputs")(dec_outputs)

    return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)

# %%
sample_transformer = transformer(
    vocab_size=8192,
    num_layers=4,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_transformer",
)

tf.keras.utils.plot_model(
    sample_transformer, to_file="transformer.png", show_shapes=True
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
def loss_function(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))

    loss = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True, reduction="none"
    )(y_true, y_pred)

    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
    loss = tf.multiply(loss, mask)

    return tf.reduce_mean(loss)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = tf.constant(d_model, dtype=tf.float32)
        self.warmup_steps = warmup_steps

    def get_config(self):
        return {"d_model": self.d_model, "warmup_steps": self.warmup_steps}

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps**-1.5)

        return tf.math.multiply(
            tf.math.rsqrt(self.d_model), tf.math.minimum(arg1, arg2)
        )

# %%
sample_learning_rate = CustomSchedule(d_model=128)

plt.plot(sample_learning_rate(tf.range(200000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %%
# clear backend
tf.keras.backend.clear_session()

learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9
)


def accuracy(y_true, y_pred):
    # ensure labels have shape (batch_size, MAX_LENGTH - 1)
    y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)


# initialize and compile model within strategy scope
with strategy.scope():
    model = transformer(
        vocab_size=VOCAB_SIZE,
        num_layers=NUM_LAYERS,
        units=UNITS,
        d_model=D_MODEL,
        num_heads=NUM_HEADS,
        dropout=DROPOUT,
    )

    model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None)]       0           []
#
#  dec_inputs (InputLayer)        [(None, None)]       0           []
#
#  enc_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  encoder (Functional)           (None, None, 256)    1357056     ['inputs[0][0]',
#                                                                   'enc_padding_mask[0][0]']
#
#  look_ahead_mask (Lambda)       (None, 1, None, Non  0           ['dec_inputs[0][0]']
#                                 e)
#
#  dec_padding_mask (Lambda)      (None, 1, 1, None)   0           ['inputs[0][0]']
#
#  decoder (Functional)           (None, None, 256)    1884416     ['dec_inputs[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'look_ahead_mask[0][0]',
#                                                                   'dec_padding_mask[0][0]']
#
#  outputs (Dense)                (None, None, 1183)   304031      ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 3,545,503
# Trainable params: 3,545,503
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(dataset, epochs=830)
# Out:
# Epoch 1/830
# 2/2 [==============================] - 5s 42ms/step - loss: 4.2491 - accuracy: 5.1800e-04
# Epoch 2/830
# 2/2 [==============================] - 0s 41ms/step - loss: 4.2465 - accuracy: 5.1800e-04
# Epoch 3/830
# 2/2 [==============================] - 0s 39ms/step - loss: 4.2427 - accuracy: 0.0010
# Epoch 4/830
# 2/2 [==============================] - 0s 33ms/step - loss: 4.2424 - accuracy: 5.1800e-04
# Epoch 5/830
# 2/2 [==============================] - 0s 32ms/step - loss: 4.2386 - accuracy: 7.7700e-04
# Epoch 6/830
# 2/2 [==============================] - 0s 26ms/step - loss: 4.2398 - accuracy: 0.0010
# Epoch 7/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2323 - accuracy: 2.5900e-04
# Epoch 8/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2293 - accuracy: 0.0010
# Epoch 9/830
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2223 - accuracy: 5.1800e-04
# Epoch 10/830
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2126 - accuracy: 7.7700e-04
# Epoch 11/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.2064 - accuracy: 7.7700e-04
# Epoch 12/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1949 - accuracy: 7.7700e-04
# Epoch 13/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1879 - accuracy: 5.1800e-04
# Epoch 14/830
# 2/2 [==============================] - 0s 22ms/step - loss: 4.1756 - accuracy: 0.0013
# Epoch 15/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1713 - accuracy: 0.0018
# Epoch 16/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1598 - accuracy: 0.0013
# Epoch 17/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.1471 - accuracy: 0.0031
# Epoch 18/830
# 2/2 [==============================] - 0s 29ms/step - loss: 4.1381 - accuracy: 0.0065
# Epoch 19/830
# 2/2 [==============================] - 0s 26ms/step - loss: 4.1203 - accuracy: 0.0130
# Epoch 20/830
# 2/2 [==============================] - 0s 26ms/step - loss: 4.1097 - accuracy: 0.0161
# Epoch 21/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0937 - accuracy: 0.0207
# Epoch 22/830
# 2/2 [==============================] - 0s 26ms/step - loss: 4.0811 - accuracy: 0.0228
# Epoch 23/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.0686 - accuracy: 0.0249
# Epoch 24/830
# 2/2 [==============================] - 0s 29ms/step - loss: 4.0526 - accuracy: 0.0254
# Epoch 25/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0418 - accuracy: 0.0259
# Epoch 26/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.0239 - accuracy: 0.0256
# Epoch 27/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0104 - accuracy: 0.0256
# Epoch 28/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9894 - accuracy: 0.0251
# Epoch 29/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9801 - accuracy: 0.0256
# Epoch 30/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9728 - accuracy: 0.0256
# Epoch 31/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9612 - accuracy: 0.0256
# Epoch 32/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9470 - accuracy: 0.0256
# Epoch 33/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9282 - accuracy: 0.0256
# Epoch 34/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9186 - accuracy: 0.0256
# Epoch 35/830
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9146 - accuracy: 0.0256
# Epoch 36/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8962 - accuracy: 0.0256
# Epoch 37/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8805 - accuracy: 0.0256
# Epoch 38/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8730 - accuracy: 0.0256
# Epoch 39/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8648 - accuracy: 0.0259
# Epoch 40/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8524 - accuracy: 0.0256
# Epoch 41/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8375 - accuracy: 0.0256
# Epoch 42/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8308 - accuracy: 0.0256
# Epoch 43/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8215 - accuracy: 0.0256
# Epoch 44/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8094 - accuracy: 0.0256
# Epoch 45/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7981 - accuracy: 0.0256
# Epoch 46/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7912 - accuracy: 0.0259
# Epoch 47/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7831 - accuracy: 0.0256
# Epoch 48/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7734 - accuracy: 0.0256
# Epoch 49/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.7570 - accuracy: 0.0256
# Epoch 50/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7565 - accuracy: 0.0256
# Epoch 51/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7444 - accuracy: 0.0262
# Epoch 52/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7357 - accuracy: 0.0256
# Epoch 53/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.7309 - accuracy: 0.0259
# Epoch 54/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7176 - accuracy: 0.0256
# Epoch 55/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7102 - accuracy: 0.0262
# Epoch 56/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7010 - accuracy: 0.0277
# Epoch 57/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.6936 - accuracy: 0.0282
# Epoch 58/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.6892 - accuracy: 0.0280
# Epoch 59/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.6803 - accuracy: 0.0285
# Epoch 60/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.6725 - accuracy: 0.0287
# Epoch 61/830
# 2/2 [==============================] - 0s 22ms/step - loss: 3.6643 - accuracy: 0.0282
# Epoch 62/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.6524 - accuracy: 0.0319
# Epoch 63/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.6468 - accuracy: 0.0319
# Epoch 64/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.6427 - accuracy: 0.0334
# Epoch 65/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.6340 - accuracy: 0.0347
# Epoch 66/830
# 2/2 [==============================] - 0s 22ms/step - loss: 3.6191 - accuracy: 0.0407
# Epoch 67/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.6149 - accuracy: 0.0389
# Epoch 68/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.6009 - accuracy: 0.0391
# Epoch 69/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5925 - accuracy: 0.0386
# Epoch 70/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5910 - accuracy: 0.0396
# Epoch 71/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.5787 - accuracy: 0.0412
# Epoch 72/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.5658 - accuracy: 0.0430
# Epoch 73/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.5588 - accuracy: 0.0448
# Epoch 74/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.5500 - accuracy: 0.0448
# Epoch 75/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.5428 - accuracy: 0.0443
# Epoch 76/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.5289 - accuracy: 0.0469
# Epoch 77/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.5231 - accuracy: 0.0453
# Epoch 78/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.5107 - accuracy: 0.0466
# Epoch 79/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.5058 - accuracy: 0.0471
# Epoch 80/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4873 - accuracy: 0.0487
# Epoch 81/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4801 - accuracy: 0.0505
# Epoch 82/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4701 - accuracy: 0.0521
# Epoch 83/830
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4666 - accuracy: 0.0521
# Epoch 84/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4492 - accuracy: 0.0521
# Epoch 85/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4387 - accuracy: 0.0536
# Epoch 86/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4248 - accuracy: 0.0518
# Epoch 87/830
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4167 - accuracy: 0.0570
# Epoch 88/830
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4106 - accuracy: 0.0578
# Epoch 89/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3915 - accuracy: 0.0575
# Epoch 90/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3859 - accuracy: 0.0591
# Epoch 91/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3766 - accuracy: 0.0596
# Epoch 92/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3608 - accuracy: 0.0622
# Epoch 93/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3527 - accuracy: 0.0601
# Epoch 94/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3410 - accuracy: 0.0629
# Epoch 95/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3235 - accuracy: 0.0645
# Epoch 96/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3126 - accuracy: 0.0645
# Epoch 97/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.3004 - accuracy: 0.0658
# Epoch 98/830
# 2/2 [==============================] - 0s 27ms/step - loss: 3.2904 - accuracy: 0.0660
# Epoch 99/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.2780 - accuracy: 0.0676
# Epoch 100/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2700 - accuracy: 0.0699
# Epoch 101/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.2537 - accuracy: 0.0655
# Epoch 102/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.2426 - accuracy: 0.0692
# Epoch 103/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.2230 - accuracy: 0.0723
# Epoch 104/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2153 - accuracy: 0.0717
# Epoch 105/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1988 - accuracy: 0.0720
# Epoch 106/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1843 - accuracy: 0.0738
# Epoch 107/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1793 - accuracy: 0.0730
# Epoch 108/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1607 - accuracy: 0.0767
# Epoch 109/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.1489 - accuracy: 0.0754
# Epoch 110/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1378 - accuracy: 0.0743
# Epoch 111/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1165 - accuracy: 0.0793
# Epoch 112/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.1081 - accuracy: 0.0793
# Epoch 113/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.0920 - accuracy: 0.0816
# Epoch 114/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0821 - accuracy: 0.0805
# Epoch 115/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.0647 - accuracy: 0.0824
# Epoch 116/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.0477 - accuracy: 0.0875
# Epoch 117/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0323 - accuracy: 0.0904
# Epoch 118/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.0191 - accuracy: 0.0919
# Epoch 119/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0071 - accuracy: 0.0925
# Epoch 120/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.9844 - accuracy: 0.0899
# Epoch 121/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.9783 - accuracy: 0.0932
# Epoch 122/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.9658 - accuracy: 0.0938
# Epoch 123/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9507 - accuracy: 0.1002
# Epoch 124/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9371 - accuracy: 0.0989
# Epoch 125/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.9203 - accuracy: 0.1041
# Epoch 126/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9014 - accuracy: 0.1013
# Epoch 127/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.8881 - accuracy: 0.1033
# Epoch 128/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.8669 - accuracy: 0.1070
# Epoch 129/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.8560 - accuracy: 0.1059
# Epoch 130/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.8415 - accuracy: 0.1088
# Epoch 131/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.8334 - accuracy: 0.1080
# Epoch 132/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.8112 - accuracy: 0.1134
# Epoch 133/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7986 - accuracy: 0.1204
# Epoch 134/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7737 - accuracy: 0.1233
# Epoch 135/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7634 - accuracy: 0.1217
# Epoch 136/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7500 - accuracy: 0.1210
# Epoch 137/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7314 - accuracy: 0.1272
# Epoch 138/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7166 - accuracy: 0.1259
# Epoch 139/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.6986 - accuracy: 0.1311
# Epoch 140/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.6908 - accuracy: 0.1305
# Epoch 141/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6638 - accuracy: 0.1360
# Epoch 142/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.6452 - accuracy: 0.1375
# Epoch 143/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6315 - accuracy: 0.1375
# Epoch 144/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.6171 - accuracy: 0.1399
# Epoch 145/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6007 - accuracy: 0.1440
# Epoch 146/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.5813 - accuracy: 0.1505
# Epoch 147/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.5727 - accuracy: 0.1479
# Epoch 148/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.5469 - accuracy: 0.1481
# Epoch 149/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.5262 - accuracy: 0.1494
# Epoch 150/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.5179 - accuracy: 0.1562
# Epoch 151/830
# 2/2 [==============================] - 0s 27ms/step - loss: 2.4944 - accuracy: 0.1601
# Epoch 152/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.4816 - accuracy: 0.1603
# Epoch 153/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.4541 - accuracy: 0.1665
# Epoch 154/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.4487 - accuracy: 0.1655
# Epoch 155/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.4346 - accuracy: 0.1709
# Epoch 156/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4167 - accuracy: 0.1709
# Epoch 157/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.3902 - accuracy: 0.1733
# Epoch 158/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.3780 - accuracy: 0.1800
# Epoch 159/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.3600 - accuracy: 0.1764
# Epoch 160/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.3461 - accuracy: 0.1774
# Epoch 161/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.3228 - accuracy: 0.1847
# Epoch 162/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.3079 - accuracy: 0.1886
# Epoch 163/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.2914 - accuracy: 0.1873
# Epoch 164/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2769 - accuracy: 0.1950
# Epoch 165/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2530 - accuracy: 0.1955
# Epoch 166/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2436 - accuracy: 0.1966
# Epoch 167/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.2192 - accuracy: 0.1997
# Epoch 168/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.2076 - accuracy: 0.2051
# Epoch 169/830
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1842 - accuracy: 0.2093
# Epoch 170/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.1659 - accuracy: 0.2056
# Epoch 171/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1483 - accuracy: 0.2090
# Epoch 172/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.1380 - accuracy: 0.2271
# Epoch 173/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.1172 - accuracy: 0.2248
# Epoch 174/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.0956 - accuracy: 0.2251
# Epoch 175/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.0788 - accuracy: 0.2297
# Epoch 176/830
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0604 - accuracy: 0.2310
# Epoch 177/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.0442 - accuracy: 0.2362
# Epoch 178/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.0366 - accuracy: 0.2479
# Epoch 179/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.0149 - accuracy: 0.2383
# Epoch 180/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9886 - accuracy: 0.2393
# Epoch 181/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.9831 - accuracy: 0.2574
# Epoch 182/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.9629 - accuracy: 0.2543
# Epoch 183/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.9408 - accuracy: 0.2549
# Epoch 184/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9274 - accuracy: 0.2613
# Epoch 185/830
# 2/2 [==============================] - 0s 28ms/step - loss: 1.8999 - accuracy: 0.2611
# Epoch 186/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8896 - accuracy: 0.2738
# Epoch 187/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8802 - accuracy: 0.2730
# Epoch 188/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8543 - accuracy: 0.2761
# Epoch 189/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.8408 - accuracy: 0.2813
# Epoch 190/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.8246 - accuracy: 0.2823
# Epoch 191/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8121 - accuracy: 0.2940
# Epoch 192/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7908 - accuracy: 0.2922
# Epoch 193/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.7740 - accuracy: 0.2909
# Epoch 194/830
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7589 - accuracy: 0.3103
# Epoch 195/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.7391 - accuracy: 0.2984
# Epoch 196/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.7187 - accuracy: 0.3136
# Epoch 197/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7024 - accuracy: 0.3152
# Epoch 198/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.6900 - accuracy: 0.3121
# Epoch 199/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.6711 - accuracy: 0.3245
# Epoch 200/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.6620 - accuracy: 0.3235
# Epoch 201/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6372 - accuracy: 0.3248
# Epoch 202/830
# 2/2 [==============================] - 0s 28ms/step - loss: 1.6236 - accuracy: 0.3367
# Epoch 203/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6110 - accuracy: 0.3323
# Epoch 204/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5911 - accuracy: 0.3341
# Epoch 205/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5797 - accuracy: 0.3478
# Epoch 206/830
# 2/2 [==============================] - 0s 28ms/step - loss: 1.5549 - accuracy: 0.3476
# Epoch 207/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5442 - accuracy: 0.3497
# Epoch 208/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.5262 - accuracy: 0.3546
# Epoch 209/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5064 - accuracy: 0.3621
# Epoch 210/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4902 - accuracy: 0.3621
# Epoch 211/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4825 - accuracy: 0.3691
# Epoch 212/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4650 - accuracy: 0.3618
# Epoch 213/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4466 - accuracy: 0.3836
# Epoch 214/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.4214 - accuracy: 0.3748
# Epoch 215/830
# 2/2 [==============================] - 0s 28ms/step - loss: 1.4169 - accuracy: 0.3737
# Epoch 216/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.4007 - accuracy: 0.3898
# Epoch 217/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.3878 - accuracy: 0.3919
# Epoch 218/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.3741 - accuracy: 0.3898
# Epoch 219/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3580 - accuracy: 0.3950
# Epoch 220/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3428 - accuracy: 0.4030
# Epoch 221/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.3242 - accuracy: 0.4074
# Epoch 222/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2991 - accuracy: 0.4157
# Epoch 223/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2967 - accuracy: 0.4116
# Epoch 224/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2739 - accuracy: 0.4136
# Epoch 225/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2586 - accuracy: 0.4232
# Epoch 226/830
# 2/2 [==============================] - 0s 34ms/step - loss: 1.2490 - accuracy: 0.4175
# Epoch 227/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2343 - accuracy: 0.4227
# Epoch 228/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2079 - accuracy: 0.4289
# Epoch 229/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2059 - accuracy: 0.4211
# Epoch 230/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1965 - accuracy: 0.4450
# Epoch 231/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1691 - accuracy: 0.4286
# Epoch 232/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1599 - accuracy: 0.4400
# Epoch 233/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1427 - accuracy: 0.4450
# Epoch 234/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1307 - accuracy: 0.4367
# Epoch 235/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1134 - accuracy: 0.4499
# Epoch 236/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1018 - accuracy: 0.4517
# Epoch 237/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0841 - accuracy: 0.4520
# Epoch 238/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0782 - accuracy: 0.4587
# Epoch 239/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0542 - accuracy: 0.4564
# Epoch 240/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0535 - accuracy: 0.4618
# Epoch 241/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.0320 - accuracy: 0.4659
# Epoch 242/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.0201 - accuracy: 0.4688
# Epoch 243/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.0018 - accuracy: 0.4665
# Epoch 244/830
# 2/2 [==============================] - 0s 22ms/step - loss: 0.9924 - accuracy: 0.4745
# Epoch 245/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9778 - accuracy: 0.4758
# Epoch 246/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9666 - accuracy: 0.4755
# Epoch 247/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.9414 - accuracy: 0.4817
# Epoch 248/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9399 - accuracy: 0.4851
# Epoch 249/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9258 - accuracy: 0.4864
# Epoch 250/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9094 - accuracy: 0.4854
# Epoch 251/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8968 - accuracy: 0.4908
# Epoch 252/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.8835 - accuracy: 0.4898
# Epoch 253/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.8731 - accuracy: 0.4962
# Epoch 254/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8574 - accuracy: 0.4999
# Epoch 255/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8445 - accuracy: 0.4988
# Epoch 256/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8302 - accuracy: 0.5105
# Epoch 257/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.8194 - accuracy: 0.5053
# Epoch 258/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.8107 - accuracy: 0.5027
# Epoch 259/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.7951 - accuracy: 0.5133
# Epoch 260/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7842 - accuracy: 0.5076
# Epoch 261/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7705 - accuracy: 0.5144
# Epoch 262/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7572 - accuracy: 0.5188
# Epoch 263/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7497 - accuracy: 0.5201
# Epoch 264/830
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7277 - accuracy: 0.5203
# Epoch 265/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.7177 - accuracy: 0.5260
# Epoch 266/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7076 - accuracy: 0.5221
# Epoch 267/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6990 - accuracy: 0.5260
# Epoch 268/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6817 - accuracy: 0.5289
# Epoch 269/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6738 - accuracy: 0.5268
# Epoch 270/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6625 - accuracy: 0.5330
# Epoch 271/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6486 - accuracy: 0.5328
# Epoch 272/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6380 - accuracy: 0.5372
# Epoch 273/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6283 - accuracy: 0.5379
# Epoch 274/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6151 - accuracy: 0.5387
# Epoch 275/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6140 - accuracy: 0.5426
# Epoch 276/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5981 - accuracy: 0.5429
# Epoch 277/830
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5833 - accuracy: 0.5493
# Epoch 278/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5718 - accuracy: 0.5499
# Epoch 279/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5678 - accuracy: 0.5442
# Epoch 280/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5510 - accuracy: 0.5501
# Epoch 281/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5406 - accuracy: 0.5501
# Epoch 282/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5268 - accuracy: 0.5535
# Epoch 283/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5266 - accuracy: 0.5480
# Epoch 284/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5101 - accuracy: 0.5543
# Epoch 285/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5062 - accuracy: 0.5543
# Epoch 286/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4918 - accuracy: 0.5566
# Epoch 287/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4776 - accuracy: 0.5581
# Epoch 288/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4762 - accuracy: 0.5594
# Epoch 289/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4606 - accuracy: 0.5615
# Epoch 290/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4501 - accuracy: 0.5615
# Epoch 291/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4473 - accuracy: 0.5631
# Epoch 292/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4361 - accuracy: 0.5600
# Epoch 293/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4190 - accuracy: 0.5662
# Epoch 294/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4150 - accuracy: 0.5667
# Epoch 295/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4067 - accuracy: 0.5664
# Epoch 296/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4001 - accuracy: 0.5672
# Epoch 297/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3873 - accuracy: 0.5685
# Epoch 298/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3829 - accuracy: 0.5680
# Epoch 299/830
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3709 - accuracy: 0.5719
# Epoch 300/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3693 - accuracy: 0.5695
# Epoch 301/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3554 - accuracy: 0.5732
# Epoch 302/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3517 - accuracy: 0.5711
# Epoch 303/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3468 - accuracy: 0.5724
# Epoch 304/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3351 - accuracy: 0.5729
# Epoch 305/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3292 - accuracy: 0.5755
# Epoch 306/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3179 - accuracy: 0.5763
# Epoch 307/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3115 - accuracy: 0.5760
# Epoch 308/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3012 - accuracy: 0.5760
# Epoch 309/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2928 - accuracy: 0.5768
# Epoch 310/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2912 - accuracy: 0.5776
# Epoch 311/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2864 - accuracy: 0.5768
# Epoch 312/830
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2771 - accuracy: 0.5783
# Epoch 313/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2693 - accuracy: 0.5786
# Epoch 314/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2659 - accuracy: 0.5799
# Epoch 315/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2574 - accuracy: 0.5789
# Epoch 316/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2517 - accuracy: 0.5789
# Epoch 317/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2475 - accuracy: 0.5799
# Epoch 318/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2380 - accuracy: 0.5812
# Epoch 319/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2355 - accuracy: 0.5799
# Epoch 320/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2256 - accuracy: 0.5812
# Epoch 321/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2243 - accuracy: 0.5815
# Epoch 322/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2151 - accuracy: 0.5812
# Epoch 323/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2136 - accuracy: 0.5822
# Epoch 324/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2039 - accuracy: 0.5822
# Epoch 325/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2031 - accuracy: 0.5830
# Epoch 326/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1974 - accuracy: 0.5825
# Epoch 327/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1953 - accuracy: 0.5815
# Epoch 328/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1863 - accuracy: 0.5833
# Epoch 329/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1856 - accuracy: 0.5835
# Epoch 330/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1771 - accuracy: 0.5825
# Epoch 331/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1736 - accuracy: 0.5840
# Epoch 332/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1694 - accuracy: 0.5835
# Epoch 333/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1647 - accuracy: 0.5820
# Epoch 334/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1614 - accuracy: 0.5843
# Epoch 335/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1548 - accuracy: 0.5846
# Epoch 336/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1538 - accuracy: 0.5835
# Epoch 337/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1501 - accuracy: 0.5840
# Epoch 338/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1438 - accuracy: 0.5843
# Epoch 339/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1418 - accuracy: 0.5840
# Epoch 340/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1364 - accuracy: 0.5843
# Epoch 341/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1352 - accuracy: 0.5843
# Epoch 342/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1332 - accuracy: 0.5848
# Epoch 343/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1270 - accuracy: 0.5846
# Epoch 344/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1231 - accuracy: 0.5840
# Epoch 345/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1199 - accuracy: 0.5840
# Epoch 346/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1174 - accuracy: 0.5848
# Epoch 347/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1146 - accuracy: 0.5848
# Epoch 348/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1127 - accuracy: 0.5846
# Epoch 349/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1081 - accuracy: 0.5843
# Epoch 350/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1061 - accuracy: 0.5846
# Epoch 351/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1023 - accuracy: 0.5843
# Epoch 352/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1018 - accuracy: 0.5843
# Epoch 353/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0982 - accuracy: 0.5846
# Epoch 354/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0955 - accuracy: 0.5848
# Epoch 355/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0928 - accuracy: 0.5843
# Epoch 356/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0897 - accuracy: 0.5848
# Epoch 357/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0880 - accuracy: 0.5846
# Epoch 358/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0843 - accuracy: 0.5848
# Epoch 359/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0824 - accuracy: 0.5848
# Epoch 360/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0812 - accuracy: 0.5846
# Epoch 361/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0793 - accuracy: 0.5848
# Epoch 362/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0784 - accuracy: 0.5846
# Epoch 363/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0772 - accuracy: 0.5848
# Epoch 364/830
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0738 - accuracy: 0.5848
# Epoch 365/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0718 - accuracy: 0.5848
# Epoch 366/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0693 - accuracy: 0.5848
# Epoch 367/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0683 - accuracy: 0.5848
# Epoch 368/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0663 - accuracy: 0.5848
# Epoch 369/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0664 - accuracy: 0.5848
# Epoch 370/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0624 - accuracy: 0.5848
# Epoch 371/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0629 - accuracy: 0.5846
# Epoch 372/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0607 - accuracy: 0.5848
# Epoch 373/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0581 - accuracy: 0.5848
# Epoch 374/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0574 - accuracy: 0.5846
# Epoch 375/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0559 - accuracy: 0.5848
# Epoch 376/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0538 - accuracy: 0.5846
# Epoch 377/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0535 - accuracy: 0.5848
# Epoch 378/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0534 - accuracy: 0.5848
# Epoch 379/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0511 - accuracy: 0.5848
# Epoch 380/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0506 - accuracy: 0.5848
# Epoch 381/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0483 - accuracy: 0.5848
# Epoch 382/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0480 - accuracy: 0.5848
# Epoch 383/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0461 - accuracy: 0.5848
# Epoch 384/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0455 - accuracy: 0.5848
# Epoch 385/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0436 - accuracy: 0.5848
# Epoch 386/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0446 - accuracy: 0.5848
# Epoch 387/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0428 - accuracy: 0.5848
# Epoch 388/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0403 - accuracy: 0.5848
# Epoch 389/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0397 - accuracy: 0.5848
# Epoch 390/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0382 - accuracy: 0.5848
# Epoch 391/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0380 - accuracy: 0.5848
# Epoch 392/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0370 - accuracy: 0.5848
# Epoch 393/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0365 - accuracy: 0.5848
# Epoch 394/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0348 - accuracy: 0.5848
# Epoch 395/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0337 - accuracy: 0.5848
# Epoch 396/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0334 - accuracy: 0.5848
# Epoch 397/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0326 - accuracy: 0.5848
# Epoch 398/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0319 - accuracy: 0.5848
# Epoch 399/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0307 - accuracy: 0.5848
# Epoch 400/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0310 - accuracy: 0.5848
# Epoch 401/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0295 - accuracy: 0.5848
# Epoch 402/830
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0290 - accuracy: 0.5848
# Epoch 403/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0284 - accuracy: 0.5848
# Epoch 404/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0273 - accuracy: 0.5848
# Epoch 405/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0271 - accuracy: 0.5848
# Epoch 406/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0268 - accuracy: 0.5848
# Epoch 407/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0262 - accuracy: 0.5848
# Epoch 408/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0259 - accuracy: 0.5848
# Epoch 409/830
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0249 - accuracy: 0.5848
# Epoch 410/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0240 - accuracy: 0.5848
# Epoch 411/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0239 - accuracy: 0.5848
# Epoch 412/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0227 - accuracy: 0.5848
# Epoch 413/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0228 - accuracy: 0.5848
# Epoch 414/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0222 - accuracy: 0.5848
# Epoch 415/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0212 - accuracy: 0.5848
# Epoch 416/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0211 - accuracy: 0.5848
# Epoch 417/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0206 - accuracy: 0.5848
# Epoch 418/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0200 - accuracy: 0.5848
# Epoch 419/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0199 - accuracy: 0.5848
# Epoch 420/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0191 - accuracy: 0.5848
# Epoch 421/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0181 - accuracy: 0.5848
# Epoch 422/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0182 - accuracy: 0.5848
# Epoch 423/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0176 - accuracy: 0.5848
# Epoch 424/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0174 - accuracy: 0.5848
# Epoch 425/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0173 - accuracy: 0.5848
# Epoch 426/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0167 - accuracy: 0.5848
# Epoch 427/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0165 - accuracy: 0.5848
# Epoch 428/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0161 - accuracy: 0.5848
# Epoch 429/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0160 - accuracy: 0.5848
# Epoch 430/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0152 - accuracy: 0.5848
# Epoch 431/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0150 - accuracy: 0.5848
# Epoch 432/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0151 - accuracy: 0.5848
# Epoch 433/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0144 - accuracy: 0.5848
# Epoch 434/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0138 - accuracy: 0.5848
# Epoch 435/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0138 - accuracy: 0.5848
# Epoch 436/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0129 - accuracy: 0.5848
# Epoch 437/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0129 - accuracy: 0.5848
# Epoch 438/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0125 - accuracy: 0.5848
# Epoch 439/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0127 - accuracy: 0.5848
# Epoch 440/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0120 - accuracy: 0.5848
# Epoch 441/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0117 - accuracy: 0.5848
# Epoch 442/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0118 - accuracy: 0.5848
# Epoch 443/830
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0115 - accuracy: 0.5848
# Epoch 444/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0109 - accuracy: 0.5848
# Epoch 445/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0109 - accuracy: 0.5848
# Epoch 446/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0106 - accuracy: 0.5848
# Epoch 447/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0106 - accuracy: 0.5848
# Epoch 448/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0099 - accuracy: 0.5848
# Epoch 449/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0101 - accuracy: 0.5848
# Epoch 450/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0098 - accuracy: 0.5848
# Epoch 451/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0095 - accuracy: 0.5848
# Epoch 452/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0093 - accuracy: 0.5848
# Epoch 453/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0093 - accuracy: 0.5848
# Epoch 454/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0089 - accuracy: 0.5848
# Epoch 455/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0088 - accuracy: 0.5848
# Epoch 456/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0085 - accuracy: 0.5848
# Epoch 457/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0082 - accuracy: 0.5848
# Epoch 458/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0081 - accuracy: 0.5848
# Epoch 459/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0080 - accuracy: 0.5848
# Epoch 460/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0078 - accuracy: 0.5848
# Epoch 461/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0076 - accuracy: 0.5848
# Epoch 462/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0073 - accuracy: 0.5848
# Epoch 463/830
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0073 - accuracy: 0.5848
# Epoch 464/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0073 - accuracy: 0.5848
# Epoch 465/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0069 - accuracy: 0.5848
# Epoch 466/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0070 - accuracy: 0.5848
# Epoch 467/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0067 - accuracy: 0.5848
# Epoch 468/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0065 - accuracy: 0.5848
# Epoch 469/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0066 - accuracy: 0.5848
# Epoch 470/830
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0063 - accuracy: 0.5848
# Epoch 471/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0061 - accuracy: 0.5848
# Epoch 472/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0061 - accuracy: 0.5848
# Epoch 473/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0059 - accuracy: 0.5848
# Epoch 474/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0057 - accuracy: 0.5848
# Epoch 475/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0056 - accuracy: 0.5848
# Epoch 476/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0055 - accuracy: 0.5848
# Epoch 477/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0055 - accuracy: 0.5848
# Epoch 478/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0051 - accuracy: 0.5848
# Epoch 479/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0053 - accuracy: 0.5848
# Epoch 480/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0049 - accuracy: 0.5848
# Epoch 481/830
# ...
# Epoch 677/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0001e-04 - accuracy: 0.5848
# Epoch 678/830
# 2/2 [==============================] - 0s 32ms/step - loss: 9.8876e-05 - accuracy: 0.5848
# Epoch 679/830
# 2/2 [==============================] - 0s 30ms/step - loss: 9.8122e-05 - accuracy: 0.5848
# Epoch 680/830
# 2/2 [==============================] - 0s 26ms/step - loss: 9.4494e-05 - accuracy: 0.5848
# Epoch 681/830
# 2/2 [==============================] - 0s 29ms/step - loss: 9.1530e-05 - accuracy: 0.5848
# Epoch 682/830
# 2/2 [==============================] - 0s 27ms/step - loss: 9.0716e-05 - accuracy: 0.5848
# Epoch 683/830
# 2/2 [==============================] - 0s 25ms/step - loss: 9.0437e-05 - accuracy: 0.5848
# Epoch 684/830
# 2/2 [==============================] - 0s 25ms/step - loss: 8.9710e-05 - accuracy: 0.5848
# Epoch 685/830
# 2/2 [==============================] - 0s 24ms/step - loss: 8.5122e-05 - accuracy: 0.5848
# Epoch 686/830
# 2/2 [==============================] - 0s 25ms/step - loss: 8.5260e-05 - accuracy: 0.5848
# Epoch 687/830
# 2/2 [==============================] - 0s 23ms/step - loss: 8.6233e-05 - accuracy: 0.5848
# Epoch 688/830
# 2/2 [==============================] - 0s 23ms/step - loss: 8.2369e-05 - accuracy: 0.5848
# Epoch 689/830
# 2/2 [==============================] - 0s 23ms/step - loss: 7.9736e-05 - accuracy: 0.5848
# Epoch 690/830
# 2/2 [==============================] - 0s 23ms/step - loss: 8.0559e-05 - accuracy: 0.5848
# Epoch 691/830
# 2/2 [==============================] - 0s 25ms/step - loss: 7.7648e-05 - accuracy: 0.5848
# Epoch 692/830
# 2/2 [==============================] - 0s 24ms/step - loss: 7.6917e-05 - accuracy: 0.5848
# Epoch 693/830
# 2/2 [==============================] - 0s 24ms/step - loss: 7.3297e-05 - accuracy: 0.5848
# Epoch 694/830
# 2/2 [==============================] - 0s 24ms/step - loss: 7.2520e-05 - accuracy: 0.5848
# Epoch 695/830
# 2/2 [==============================] - 0s 26ms/step - loss: 7.4881e-05 - accuracy: 0.5848
# Epoch 696/830
# 2/2 [==============================] - 0s 24ms/step - loss: 7.3245e-05 - accuracy: 0.5848
# Epoch 697/830
# 2/2 [==============================] - 0s 24ms/step - loss: 6.9862e-05 - accuracy: 0.5848
# Epoch 698/830
# 2/2 [==============================] - 0s 23ms/step - loss: 6.8000e-05 - accuracy: 0.5848
# Epoch 699/830
# 2/2 [==============================] - 0s 24ms/step - loss: 6.7251e-05 - accuracy: 0.5848
# Epoch 700/830
# 2/2 [==============================] - 0s 28ms/step - loss: 6.5068e-05 - accuracy: 0.5848
# Epoch 701/830
# 2/2 [==============================] - 0s 24ms/step - loss: 6.4812e-05 - accuracy: 0.5848
# Epoch 702/830
# 2/2 [==============================] - 0s 25ms/step - loss: 6.6630e-05 - accuracy: 0.5848
# Epoch 703/830
# 2/2 [==============================] - 0s 23ms/step - loss: 6.2298e-05 - accuracy: 0.5848
# Epoch 704/830
# 2/2 [==============================] - 0s 24ms/step - loss: 5.9491e-05 - accuracy: 0.5848
# Epoch 705/830
# 2/2 [==============================] - 0s 29ms/step - loss: 6.0303e-05 - accuracy: 0.5848
# Epoch 706/830
# 2/2 [==============================] - 0s 22ms/step - loss: 5.7491e-05 - accuracy: 0.5848
# Epoch 707/830
# 2/2 [==============================] - 0s 25ms/step - loss: 6.1232e-05 - accuracy: 0.5848
# Epoch 708/830
# 2/2 [==============================] - 0s 25ms/step - loss: 5.5709e-05 - accuracy: 0.5848
# Epoch 709/830
# 2/2 [==============================] - 0s 24ms/step - loss: 5.5226e-05 - accuracy: 0.5848
# Epoch 710/830
# 2/2 [==============================] - 0s 23ms/step - loss: 5.5535e-05 - accuracy: 0.5848
# Epoch 711/830
# 2/2 [==============================] - 0s 27ms/step - loss: 5.4617e-05 - accuracy: 0.5848
# Epoch 712/830
# 2/2 [==============================] - 0s 24ms/step - loss: 5.2043e-05 - accuracy: 0.5848
# Epoch 713/830
# 2/2 [==============================] - 0s 24ms/step - loss: 5.2558e-05 - accuracy: 0.5848
# Epoch 714/830
# 2/2 [==============================] - 0s 25ms/step - loss: 5.1141e-05 - accuracy: 0.5848
# Epoch 715/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.7934e-05 - accuracy: 0.5848
# Epoch 716/830
# 2/2 [==============================] - 0s 23ms/step - loss: 5.0050e-05 - accuracy: 0.5848
# Epoch 717/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.7016e-05 - accuracy: 0.5848
# Epoch 718/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.5619e-05 - accuracy: 0.5848
# Epoch 719/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.5482e-05 - accuracy: 0.5848
# Epoch 720/830
# 2/2 [==============================] - 0s 30ms/step - loss: 4.6712e-05 - accuracy: 0.5848
# Epoch 721/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.6383e-05 - accuracy: 0.5848
# Epoch 722/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.5452e-05 - accuracy: 0.5848
# Epoch 723/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.5403e-05 - accuracy: 0.5848
# Epoch 724/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3238e-05 - accuracy: 0.5848
# Epoch 725/830
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1634e-05 - accuracy: 0.5848
# Epoch 726/830
# 2/2 [==============================] - 0s 28ms/step - loss: 4.1700e-05 - accuracy: 0.5848
# Epoch 727/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0647e-05 - accuracy: 0.5848
# Epoch 728/830
# 2/2 [==============================] - 0s 24ms/step - loss: 4.0256e-05 - accuracy: 0.5848
# Epoch 729/830
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0620e-05 - accuracy: 0.5848
# Epoch 730/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9189e-05 - accuracy: 0.5848
# Epoch 731/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8876e-05 - accuracy: 0.5848
# Epoch 732/830
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7871e-05 - accuracy: 0.5848
# Epoch 733/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.5312e-05 - accuracy: 0.5848
# Epoch 734/830
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4862e-05 - accuracy: 0.5848
# Epoch 735/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4678e-05 - accuracy: 0.5848
# Epoch 736/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3792e-05 - accuracy: 0.5848
# Epoch 737/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3112e-05 - accuracy: 0.5848
# Epoch 738/830
# 2/2 [==============================] - 0s 28ms/step - loss: 3.2908e-05 - accuracy: 0.5848
# Epoch 739/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2796e-05 - accuracy: 0.5848
# Epoch 740/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1456e-05 - accuracy: 0.5848
# Epoch 741/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.0838e-05 - accuracy: 0.5848
# Epoch 742/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0604e-05 - accuracy: 0.5848
# Epoch 743/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.9758e-05 - accuracy: 0.5848
# Epoch 744/830
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0558e-05 - accuracy: 0.5848
# Epoch 745/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.9158e-05 - accuracy: 0.5848
# Epoch 746/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.8561e-05 - accuracy: 0.5848
# Epoch 747/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7959e-05 - accuracy: 0.5848
# Epoch 748/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7853e-05 - accuracy: 0.5848
# Epoch 749/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7659e-05 - accuracy: 0.5848
# Epoch 750/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6917e-05 - accuracy: 0.5848
# Epoch 751/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6113e-05 - accuracy: 0.5848
# Epoch 752/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.5300e-05 - accuracy: 0.5848
# Epoch 753/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4033e-05 - accuracy: 0.5848
# Epoch 754/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4559e-05 - accuracy: 0.5848
# Epoch 755/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.3415e-05 - accuracy: 0.5848
# Epoch 756/830
# 2/2 [==============================] - 0s 22ms/step - loss: 2.3299e-05 - accuracy: 0.5848
# Epoch 757/830
# 2/2 [==============================] - 0s 23ms/step - loss: 2.3124e-05 - accuracy: 0.5848
# Epoch 758/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2359e-05 - accuracy: 0.5848
# Epoch 759/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.2992e-05 - accuracy: 0.5848
# Epoch 760/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2078e-05 - accuracy: 0.5848
# Epoch 761/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2691e-05 - accuracy: 0.5848
# Epoch 762/830
# 2/2 [==============================] - 0s 27ms/step - loss: 2.1406e-05 - accuracy: 0.5848
# Epoch 763/830
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1636e-05 - accuracy: 0.5848
# Epoch 764/830
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0422e-05 - accuracy: 0.5848
# Epoch 765/830
# 2/2 [==============================] - 0s 29ms/step - loss: 1.9339e-05 - accuracy: 0.5848
# Epoch 766/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.0112e-05 - accuracy: 0.5848
# Epoch 767/830
# 2/2 [==============================] - 0s 32ms/step - loss: 1.9550e-05 - accuracy: 0.5848
# Epoch 768/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8792e-05 - accuracy: 0.5848
# Epoch 769/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8464e-05 - accuracy: 0.5848
# Epoch 770/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8165e-05 - accuracy: 0.5848
# Epoch 771/830
# 2/2 [==============================] - 0s 27ms/step - loss: 1.7578e-05 - accuracy: 0.5848
# Epoch 772/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.7296e-05 - accuracy: 0.5848
# Epoch 773/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6831e-05 - accuracy: 0.5848
# Epoch 774/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7226e-05 - accuracy: 0.5848
# Epoch 775/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7202e-05 - accuracy: 0.5848
# Epoch 776/830
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6744e-05 - accuracy: 0.5848
# Epoch 777/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.3655e-05 - accuracy: 0.5848
# Epoch 778/830
# 2/2 [==============================] - 0s 27ms/step - loss: 5.0961e-04 - accuracy: 0.5846
# Epoch 779/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 0.5846
# Epoch 780/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0026 - accuracy: 0.5846
# Epoch 781/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0037 - accuracy: 0.5840
# Epoch 782/830
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0034 - accuracy: 0.5843
# Epoch 783/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.4656e-04 - accuracy: 0.5848
# Epoch 784/830
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0027 - accuracy: 0.5840
# Epoch 785/830
# 2/2 [==============================] - 0s 25ms/step - loss: 9.1601e-04 - accuracy: 0.5843
# Epoch 786/830
# 2/2 [==============================] - 0s 24ms/step - loss: 9.2332e-04 - accuracy: 0.5846
# Epoch 787/830
# 2/2 [==============================] - 0s 24ms/step - loss: 7.3762e-04 - accuracy: 0.5846
# Epoch 788/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0097 - accuracy: 0.5833
# Epoch 789/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0062 - accuracy: 0.5822
# Epoch 790/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0052 - accuracy: 0.5838
# Epoch 791/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 0.5846
# Epoch 792/830
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0019 - accuracy: 0.5846
# Epoch 793/830
# 2/2 [==============================] - 0s 25ms/step - loss: 9.3653e-04 - accuracy: 0.5848
# Epoch 794/830
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0013 - accuracy: 0.5848
# Epoch 795/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0028 - accuracy: 0.5843
# Epoch 796/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 0.5846
# Epoch 797/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0045 - accuracy: 0.5840
# Epoch 798/830
# 2/2 [==============================] - 0s 27ms/step - loss: 5.8273e-04 - accuracy: 0.5848
# Epoch 799/830
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0030 - accuracy: 0.5846
# Epoch 800/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5999e-04 - accuracy: 0.5848
# Epoch 801/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0018 - accuracy: 0.5846
# Epoch 802/830
# 2/2 [==============================] - 0s 25ms/step - loss: 5.5927e-04 - accuracy: 0.5848
# Epoch 803/830
# 2/2 [==============================] - 0s 25ms/step - loss: 2.6537e-04 - accuracy: 0.5848
# Epoch 804/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0052 - accuracy: 0.5843
# Epoch 805/830
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0018 - accuracy: 0.5846
# Epoch 806/830
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9856e-04 - accuracy: 0.5848
# Epoch 807/830
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 0.5846
# Epoch 808/830
# 2/2 [==============================] - 0s 27ms/step - loss: 7.3172e-04 - accuracy: 0.5848
# Epoch 809/830
# 2/2 [==============================] - 0s 26ms/step - loss: 3.0241e-04 - accuracy: 0.5848
# Epoch 810/830
# 2/2 [==============================] - 0s 23ms/step - loss: 3.0453e-04 - accuracy: 0.5848
# Epoch 811/830
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2155e-04 - accuracy: 0.5848
# Epoch 812/830
# 2/2 [==============================] - 0s 28ms/step - loss: 2.2123e-04 - accuracy: 0.5848
# Epoch 813/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.7166e-04 - accuracy: 0.5848
# Epoch 814/830
# 2/2 [==============================] - 0s 25ms/step - loss: 3.0095e-04 - accuracy: 0.5848
# Epoch 815/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.3937e-04 - accuracy: 0.5848
# Epoch 816/830
# 2/2 [==============================] - 0s 26ms/step - loss: 1.3409e-04 - accuracy: 0.5848
# Epoch 817/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1248e-04 - accuracy: 0.5848
# Epoch 818/830
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0810e-04 - accuracy: 0.5848
# Epoch 819/830
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0734e-04 - accuracy: 0.5848
# Epoch 820/830
# 2/2 [==============================] - 0s 23ms/step - loss: 9.9619e-05 - accuracy: 0.5848
# Epoch 821/830
# 2/2 [==============================] - 0s 24ms/step - loss: 8.5019e-05 - accuracy: 0.5848
# Epoch 822/830
# 2/2 [==============================] - 0s 24ms/step - loss: 8.8940e-05 - accuracy: 0.5848
# Epoch 823/830
# 2/2 [==============================] - 0s 24ms/step - loss: 8.6035e-05 - accuracy: 0.5848
# Epoch 824/830
# 2/2 [==============================] - 0s 23ms/step - loss: 7.1929e-05 - accuracy: 0.5848
# Epoch 825/830
# 2/2 [==============================] - 0s 24ms/step - loss: 6.6662e-05 - accuracy: 0.5848
# Epoch 826/830
# 2/2 [==============================] - 0s 25ms/step - loss: 6.4138e-05 - accuracy: 0.5848
# Epoch 827/830
# 2/2 [==============================] - 0s 25ms/step - loss: 6.9122e-05 - accuracy: 0.5848
# Epoch 828/830
# 2/2 [==============================] - 0s 24ms/step - loss: 5.6088e-05 - accuracy: 0.5848
# Epoch 829/830
# 2/2 [==============================] - 0s 26ms/step - loss: 5.2761e-05 - accuracy: 0.5848
# Epoch 830/830
# 2/2 [==============================] - 0s 27ms/step - loss: 5.5287e-05 - accuracy: 0.5848

# %%
filename = "model.h5"
tf.keras.models.save_model(model, filepath=filename, include_optimizer=False)

# %%
filename = "model.h5"
model = tf.keras.models.load_model(
    filename,
    custom_objects={
        "PositionalEncoding": PositionalEncoding,
        "MultiHeadAttentionLayer": MultiHeadAttentionLayer,
    },
    compile=False,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 filename = "model.h5"
# ----> 2 model = tf.keras.models.load_model(
#       3     filename,
#       4     custom_objects={
#       5         "PositionalEncoding": PositionalEncoding,
#       6         "MultiHeadAttentionLayer": MultiHeadAttentionLayer,
#       7     },
#       8     compile=False,
#       9 )
#
# File ~/anaconda3/envs/genai/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/Documents/LynchStreamlit/Transformer.py:220, in create_look_ahead_mask(x)
#     218 seq_len = tf.shape(x)[1]
#     219 look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
# --> 220 padding_mask = create_padding_mask(x)
#     221 return tf.maximum(look_ahead_mask, padding_mask)
#
# NameError: Exception encountered when calling layer "look_ahead_mask" (type Lambda).
#
# name 'create_padding_mask' is not defined
#
# Call arguments received by layer "look_ahead_mask" (type Lambda):
#   • inputs=tf.Tensor(shape=(None, None), dtype=float32)
#   • mask=None
#   • training=False

# %%
def evaluate(sentence):
    sentence = preprocess_sentence(sentence)

    sentence = tf.expand_dims(
        START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0
    )

    output = tf.expand_dims(START_TOKEN, 0)

    for i in range(MAX_LENGTH):
        predictions = model(inputs=[sentence, output], training=False)

        # select the last word from the seq_len dimension
        predictions = predictions[:, -1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        # return the result if the predicted_id is equal to the end token
        if tf.equal(predicted_id, END_TOKEN[0]):
            break

        # concatenated the predicted_id to the output which is given to the decoder
        # as its input.
        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0)


def predict(sentence):
    prediction = evaluate(sentence)
    predicted_sentence = tokenizer.decode(
        [i for i in prediction if i < tokenizer.vocab_size]
    )
    return predicted_sentence

# %%
predict("Who is peter lynch?")
# Out:
# 'giving giving giving giving giving giving giving independent them them giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving '

# %%
predict("What is Lynch's ideology for trading?")
# Out:
# 'giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving giving '

# %%
predict("What is Lynch's best investments?")
# Out:
# '����analysis analysis them them them them them them them them them them them them them them them them them them them them them them them them them them them them them them them them them them '
